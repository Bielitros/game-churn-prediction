# %%
import pandas as pd
import matplotlib.pyplot as plt

pd.set_option("display.max_columns", None)

# %%
df = pd.read_csv("../data/raw/steam_games_dataset.csv")

df.head()

# %%
print("Quantidade de linhas:", df.shape[0])
print("Quantidade de colunas:", df.shape[1])

df.info()

# %%
df.isnull().sum()

# %%
df.describe()

# %%
classes = df["status"].value_counts().sort_index()

classes.index = [
    "Ativo",
    "Possível Churn",
    "Churn"
]

print(classes)

# %%
classes.plot(
    kind="bar"
)

plt.title(
    "Distribuição das Classes"
)

plt.xlabel(
    "Classe"
)

plt.ylabel(
    "Quantidade"
)

plt.tight_layout()

plt.show()

# %%
correlation = df[
    [
        "playtime_forever",
        "game_count",
        "recent_active_games",
        "avg_playtime",
        "top_game_ratio"
    ]
].corr()

correlation

# %%
features = [
    "playtime_forever",
    "game_count",
    "recent_active_games",
    "avg_playtime",
    "top_game_ratio"
]

print("Features utilizadas no modelo:")

for feature in features:
    print("-", feature)

# %%
print("""
Principais observações:

- O dataset possui aproximadamente 3500 usuários.
- A classe churn é predominante.
- Existem diferenças relevantes entre as classes.
- A feature recent_active_games mostrou-se importante
  para a identificação de churn durante os experimentos.
""")
